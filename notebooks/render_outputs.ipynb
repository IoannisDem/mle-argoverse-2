# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from pathlib import Path
import utils

# %%
current_path = Path.cwd()

data_path = current_path.parent / "data" / "raw" / "episode_000"

images = np.load(data_path / "images.npy")
states = np.load(data_path / "states.npy")
actions = np.load(data_path / "actions.npy")

# %%
image_one = images[-1, :, :, :, 0]
plt.imshow(image_one)

# %%
meta_json = data_path / "meta.json"
meta = utils.read_json(meta_json)

# %%
meta
# Out:
# {'episode_idx': 0,
#  'seed': 0,
#  'num_steps': 480,
#  'success': False,
#  'crash': True,
#  'out_of_road': False,
#  'route_completion': 0.46942853436688947}
