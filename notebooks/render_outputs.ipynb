# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
images = np.load(
    r".\data\raw\episode_000\images.npy",
)
states = np.load(
    r".\data\raw\episode_000\states.npy"
)
actions = np.load(
    r".\data\raw\episode_000\actions.npy"
)

# %%
images.shape

# %%
image_one = images[-1, :, :, :, 0]
image_one.shape

# %%
plt.imshow(image_one)

# %%
states[-1]

# %%
actions[-1]
