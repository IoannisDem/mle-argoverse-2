# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from pathlib import Path
import utils

# %%
current_path = Path.cwd()

data_path = current_path.parent / "data" / "raw" / "traffic_0.15_accident_0_steps_1000" / "episode_000"

images = np.load(data_path / "images.npy")
states = np.load(data_path / "states.npy")
actions = np.load(data_path / "actions.npy")

# %%
image_one = images[-1, :, :, :, 0]
plt.imshow(image_one)

# %%
meta_json = data_path / "meta.json"
meta = utils.read_json(meta_json)

# %%
meta
# Out:
# {'episode_idx': 0,
#  'seed': 101,
#  'num_steps': 540,
#  'overtake_vehicle_num': 0,
#  'velocity': 6.990654169162262,
#  'steering': 0.023784926161170006,
#  'acceleration': 0.8333923816680908,
#  'step_energy': 0.02842157237815279,
#  'episode_energy': 18.395806812567674,
#  'policy': 'ExpertPolicy',
#  'navigation_command': 'forward',
#  'navigation_forward': True,
#  'navigation_left': False,
#  'navigation_right': False,
#  'crash_vehicle': False,
#  'crash_object': False,
#  'crash_building': False,
#  'crash_human': False,
#  'crash_sidewalk': False,
#  'out_of_road': False,
#  'arrive_dest': True,
#  'max_step': False,
#  'env_seed': 101,
#  'crash': False,
#  'step_reward': 0.7113947783255177,
#  'route_completion': 0.9896077023088309,
#  'cost': 0,
#  'episode_reward': 444.5477949219902,
#  'episode_length': 540}
